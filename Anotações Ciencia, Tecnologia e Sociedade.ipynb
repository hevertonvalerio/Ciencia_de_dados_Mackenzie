# %% [markdown]
# # Anotações Ciencia, Tecnologia e Sociedade

# %% [markdown]
# **Objetivo da aula**
#
# Apresentar a distinção entre os conceitos clássico e moderno de ciência, a fim de que você seja capaz de elaborar uma visão clara da integração entre ciência, tecnologia e sociedade.

# %% [markdown]
# -----

# %% [markdown]
# Thaumadzein - Esfera do **Espanto**
# (Observar aquilo que não conhecemos)
#
# Doxadzein - Esfera das **Opiniões**
# (O sistema 1 rápidamente cria intereprações sobre o observado)
