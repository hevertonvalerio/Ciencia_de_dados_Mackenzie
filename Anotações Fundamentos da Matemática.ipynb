# %% [markdown]
# # Anotações Fundamentos da Matemática

# %% [markdown]
# **Objetivo da aula**
#
# Apresentar o conceito de matriz, bem como definir as operações básicas de soma, subtração e multiplicação de matrizes. Definir os conceitos de matriz transposta, matriz inversa e matriz identidade. Criar uma conexão com os Sistemas Lineares, tópico da próxima aula.

# %% [markdown]
# ----
