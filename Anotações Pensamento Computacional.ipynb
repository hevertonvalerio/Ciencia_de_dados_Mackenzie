# %% [markdown]
# # Anotações Pensamento Computacional

# %% [markdown]
# **Objetivo**: Apresentar os conceitos fundamentais de pensamento computacional, trabalhando com o processo de estruturação do pensamento e os pilares do pensamento computacional apresentados por Brackmann. Por fim, será discutido especificamente o pilar da Decomposição.

# %% [markdown]
# Video Aula 1

# %% [markdown]
# Filho vá a padaria e traga 5 pães e se tiver leite, traga dois. 😁

# %% [markdown]
# **4 etapas do pensamento computacional**
# - Decomposição de problemas
# - Reconhecimento de padrões
# - Abstração (compreender o que é importante e o que não é)
# - Algorítimo (Estrutura com os comandos, instrução da solução)
